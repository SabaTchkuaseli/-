# %%
import sqlite3
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import bar_label


conn = sqlite3.connect('uclfinalurebi.sqlite')
cursor = conn.cursor()


#ეს ბრძანება წერს უეფას ჩემპიონთა ლიგის პირველი 5 ტურნირის ფინალისტების შესახებ ინფორმაციას.

cursor.execute("SELECT * FROM uclfinalll")
records = cursor.fetchmany(5)
for record in records:
    print(record)


#ეს ბრძანება წერს უეფას ჩემპიონთა ლიგის ფინალის შესახებ ინფორმაციას იმ წლებში,
# როდესაც რეალ მადრიდი გახდა ჩემპიონი.

pr_value = "Real Madrid"
cursor.execute("SELECT * FROM uclfinalll WHERE winner=:pr" , {'pr':pr_value})
records = cursor.fetchall()
for record in records:
    print(record)

# ეს ფუნქცია მომხმარებელს ცხრილში(ბაზაში) ამატებინებს მონაცემებს.

f_season = int(input("შეიყვანეთ თქვენთვის სასურველი სეზონის თარიღი "))
f_winner_country = input("თქვენი აზრით რომელი ქვეყნიდან იქნება გამარჯვებული? ")
f_winner = input("თქვენი აზრით რომელი გუნდი მოიგებს ჩემპიონატს ")
f_score = input('გვითხარი რა ანგარიშით დასრულდება თამაში ')
f_runner_up = input("გვითხარი რომელი გუნდი წააგებს ჩემპიონატს ")
f_runner_up_country = input("გვითხარი რომელი ქვეყნის გუნდი გავა მეორე ადგილზე ")
f_stadium = input("რომელ სტადიონზე გაიმართება თამაში ")
f_final_city = input("რომელ ქალაქში გაიმართება თამაში ")
f_final_country = input("რომელ ქვეყანაში გაიმართება თამაში ")
f_attendance = int(input("რამდენი ადამიანი დაესწრება თამაშს "))
f_winning_way = input("როგორ მოიგებს თამაშს გუნდი ")
cursor.execute('INSERT INTO uclfinalll (season, winner_country, winner,'
               'score, runner_up, runner_up_country, stadium, final_city, '
               'final_country, attendance,winning_way) VALUES (?, ?, ? , ?, ?, ?, ?, ?, ?, ?, ?)',
               (f_season, f_winner_country, f_winner, f_score, f_runner_up,
                f_runner_up_country,f_stadium,f_final_city,f_final_country,f_attendance,
                f_winning_way))
conn.commit()


#ეს ფუნქცია მომხმარებელს ბაზიდან აშლევინებს სასურველ მონაცემს.

x = input("რისი წაშლა გსურს(სეზონის,გამარჯვებული გუნდის,ანგარიშის,წაგებული გუნდის,წაგებული ქვეყნის,სტადიონის,"
          "ფინალის მასპინძელი ქალაქის,ფნალის მასპინძელი ქვეყნის,დასწრების,მოგების გზის) ")
# if x == 'სეზონის':
#     y = int(input("რომელი სეზონის წაშლა დინდა?"))
#     query = "DELETE FROM uclfinalll WHERE season='y'"
#     cursor.execute(query)
#     print(cursor.rowcount)
#     conn.commit()

elif x == 'გამარჯვებული ქვეყნის':
    c = input("რომელი ქვეყნის წაშლა დინდა? ")
    query = "DELETE FROM uclfinalll WHERE winner_country='c'"
    cursor.execute(query)
    print(cursor.rowcount)
    conn.commit()
# elif x == 'გამარჯვებული გუნდის':
#     w = input("რომელი გამარჯვებულის წაშლა დინდა? ")
#     query = "DELETE FROM uclfinalll WHERE winner='w'"
#     cursor.execute(query)
#     print(cursor.rowcount)
#     conn.commit()
# elif x == "ანგარიშის":
#     s = input("რომელი ანგარიშის წაშლა დინდა? ")
#     query = "DELETE FROM uclfinalll WHERE score='s'"
#     cursor.execute(query)
#     print(cursor.rowcount)
#     conn.commit()
# elif x == 'წაგებული გუნდი':
#     r = input("რომელი ფინალისრის წაშლა დინდა? ")
#     query = "DELETE FROM uclfinalll WHERE runner_up='r'"
#     cursor.execute(query)
#     print(cursor.rowcount)
#     conn.commit()
# elif x == 'წაგებული ქვეყნის':
#     ruc = input("რომელი ფინალისტი ქვეყნის წაშლა დინდა? ")
#     query = "DELETE FROM uclfinalll WHERE runner_up_country='ruc'"
#     cursor.execute(query)
#     print(cursor.rowcount)
#     conn.commit()
# elif x == 'სტადიონის':
#     st = input("რომელი სტადიონის წაშლა დინდა? ")
#     query = "DELETE FROM uclfinalll WHERE stadium='st'"
#     cursor.execute(query)
#     print(cursor.rowcount)
#     conn.commit()
# elif x == 'ფინალის მასპინძელი ქალაქის':
#     fc = input("რომელი მასპინძელი ქალაქის წაშლა დინდა? ")
#     query = "DELETE FROM uclfinalll WHERE final_city='fc'"
#     cursor.execute(query)
#     print(cursor.rowcount)
#     conn.commit()
# elif x == 'ფინალის მასპინძელი ქვეყნის':
#     fic = input("რომელი ფინალის მასპინძელი ქვეყნის წაშლა დინდა? ")
#     query = "DELETE FROM uclfinalll WHERE final_country='fic'"
#     cursor.execute(query)
#     print(cursor.rowcount)
#     conn.commit()
# elif x == "დასწრების":
#     a = input("რომელი დასწრების წაშლა დინდა? ")
#     query = "DELETE FROM uclfinalll WHERE attendance='a'"
#     cursor.execute(query)
#     print(cursor.rowcount)
#     conn.commit()
# elif x == "მოგების გზის":
#     ww = input("რომელი მოგების გზის წაშლა დინდა? ")
#     query = "DELETE FROM uclfinalll WHERE winning_way='ww'"
#     cursor.execute(query)
#     print(cursor.rowcount)
#     conn.commit()
else:
    print("კიდევ სცადე")




#ეს დიაგრამა გვიჩვენებს ჩემპიონთა ლიგის გამარჯვებულ გუნდებს რომლებმაც 3-ჯერ და მეტჯერ მოიგეს ეს ტურნირი
import matplotlib.pyplot as plt
import numpy as np

labels = ("Real Madrid", "Milan" ,"Bayern Munich" ,"liverpool" ,"Barcelona" ,
          "Ajax", "Inter Milan", "Manchester United")
champions = {
    'ჩემპიონი': (15, 7, 6, 6, 5, 4, 3, 3),
    'ფინალისტი': (3, 5, 8, 6 ,8 ,9 ,0 , 6),
}

x = np.arange(len(labels))
width = 0.15
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in champions.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1


ax.set_ylabel('რაოდენობა')
ax.set_title('საუკეთესო გუნდები ტიტულების მიხედვით')
ax.set_xticks(x + width, labels)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 20)

plt.show()




#ეს დიაგრამა აჩვენებს ჩემპიონთა ლიგის ფინალის მასპინძელი ქალაქების პროცენტულ მაჩვენებელს
import matplotlib.pyplot as plt

labels = ['ლონდონი', 'მილანი', 'მიუნხენი', 'რომი', 'ვენა', 'ბრიუსელი', 'მადრიდი', 'სხვა']
sizes = [7, 4, 4, 4, 4, 4, 5, 36]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
ax.set_title('ჩემპიონთა ლიგის ფინალის მასპინძელი ქალაქები')

plt.show()

# ეს დიაგრამა გვიჩვენებს თუ რა გზით მოიგეს კლუბებმა ფინალი
fig, ax = plt.subplots()

winning_way = ['ძირითადი დრო', 'ექსტა ტაიმი', 'პენლები', 'გამეორება']
counts = [52, 5, 11, 1]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(winning_way, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('გამარჯვების გზები')
ax.set_title('ფინალის მოგების გზები')
ax.legend(title='ფერები')

plt.show()







conn.close()
# Out:
# ('1955–56', 'Spain', 'Real Madrid', '4–3', 'Reims', 'France', 'Parc des Princes', 'Paris', 'France', '38239', 'normal time')
# ('1956–57', 'Spain', 'Real Madrid', '2–0', 'Fiorentina', 'Italy', 'Santiago Bernabéu', 'Madrid', 'Spain', '124000', 'normal time')
# ('1957–58', 'Spain', 'Real Madrid', '3–2', 'Milan', 'Italy', 'Heysel Stadium', 'Brussels', 'Belgium', '67000', 'extra time')
# ('1958–59', 'Spain', 'Real Madrid', '2–0', 'Reims', 'France', 'Neckarstadion', 'Stuttgart', 'West Germany', '72000', 'normal time')
# ('1959–60', 'Spain', 'Real Madrid', '7–3', 'Eintracht Frankfurt', 'West Germany', 'Hampden Park', 'Glasgow', 'Scotland', '127621', 'normal time')
# ('1955–56', 'Spain', 'Real Madrid', '4–3', 'Reims', 'France', 'Parc des Princes', 'Paris', 'France', '38239', 'normal time')
# ('1956–57', 'Spain', 'Real Madrid', '2–0', 'Fiorentina', 'Italy', 'Santiago Bernabéu', 'Madrid', 'Spain', '124000', 'normal time')
# ...
